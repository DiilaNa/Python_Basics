# %%
import math
def find_sqroot(x):
    print(f"Sqaure root of {x} is {math.sqrt(x)}")

find_sqroot(2)
# Out:
# Sqaure root of 2 is 1.4142135623730951

# %%
def find_factorial(x):
    print(f"Factorial of {x} is {math.factorial(x)}")

find_factorial(2)
# Out:
# Factorial of 2 is 2

# %% [markdown]
# - Modules are inside packages
